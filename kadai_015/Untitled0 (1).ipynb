# %%
class Human:
  def __init__(self, name, age):

    self.name = name
    self.age = age

  def printinfo(self):
    print("名前: " + self.name)
    print("年齢: " + str(self.age))

person = Human("田中 太郎", 25)

person.printinfo()
# Out:
# 名前: 田中 太郎
# 年齢: 25

# %% [markdown]
# ### `Human`クラスにメソッドを追加する例
#
# `greet`というメソッドを追加して、挨拶ができるようにしてみましょう。
